# %%
# !pip install -U finance-datareader

# %% [markdown]
# # 코스피 지수 출력

# %%
import FinanceDataReader as fdr

# KS11 (KOSPI 지수), 2020년~현재
df = fdr.DataReader('KS11', '2020')
df['Close'].plot()

# %%
# KQ11 (KOSDAQ 지수), 2020년~현재
df = fdr.DataReader('KQ11', '2020')
df['Close'].plot()
